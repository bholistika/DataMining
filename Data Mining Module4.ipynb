# %% [markdown]
# <a href="https://colab.research.google.com/github/bholistika/DataMining/blob/main/Data%20Mining%20Module4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Malika Brown
#
# Tia Robbins
#
# Marjorie Gilles
#
# Barbara Fernandez

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/trob001/Modd4/refs/heads/main/Leads.csv')
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                                Prospect ID  Lead Number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                         API      Olark Chat           No          No
# 1                         API  Organic Search           No          No
# ...

# %%
df.shape
# Out:
# (9240, 37)

# %%
df.head().T
# Out:
#                                                                                   0  \
# Prospect ID                                    7927b2df-8bba-4d29-b9a2-b6e0beafe620
# Lead Number                                                                  660737
# Lead Origin                                                                     API
# Lead Source                                                              Olark Chat
# Do Not Email                                                                     No
# Do Not Call                                                                      No
# Converted                                                                         0
# TotalVisits                                                                     0.0
# Total Time Spent on Website                                                       0
# Page Views Per Visit                                                            0.0
# ...

# %%
df.dtypes
# Out:
# Prospect ID                                       object
# Lead Number                                        int64
# Lead Origin                                       object
# Lead Source                                       object
# Do Not Email                                      object
# Do Not Call                                       object
# Converted                                          int64
# TotalVisits                                      float64
# Total Time Spent on Website                        int64
# Page Views Per Visit                             float64
# Last Activity                                     object
# Country                                           object
# Specialization                                    object
# How did you hear about X Education                object
# What is your current occupation                   object
# What matters most to you in choosing a course     object
# ...

# %%
df['TotalVisits'] = pd.to_numeric(df['TotalVisits'], errors='coerce')
df['TotalVisits'] = df['TotalVisits'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9240 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#                             prospect_id  lead_number              lead_origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      api
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      api
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  landing_page_submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  landing_page_submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  landing_page_submission
#
#       lead_source do_not_email do_not_call  converted  totalvisits  \
# 0      olark_chat           no          no          0          0.0
# 1  organic_search           no          no          0          5.0
# 2  direct_traffic           no          no          1          2.0
# 3  direct_traffic           no          no          0          1.0
# 4          google           no          no          1          2.0
#
#    total_time_spent_on_website  page_views_per_visit  ...  \
# ...

# %%
df.lead_number = (df.lead_number == 'yes').astype(int)

# %%
from sklearn.model_selection import train_test_split
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_train_full, test_size=0.33, random_state=11)

# %%
y_train = df_train.lead_number.values
y_val = df_val.lead_number.values

# %%
del df_train['lead_number']
del df_val['lead_number']

# %%
dir()
# Out:
# ['In',
#  'LogisticRegression',
#  'Out',
#  '_',
#  '_11',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'col',
#  'df',
#  'df_test',
#  'df_train',
#  'df_train_full',
#  'df_val',
#  'exit',
#  'get_ipython',
#  'model',
#  'np',
#  'pd',
#  'plt',
#  'quit',
#  'sns',
#  'string_columns',
#  'train_test_split',
#  'y_train',
#  'y_val']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "from sklearn.linear_model import LogisticRegression\nmodel = LogisticRegression(solver='liblinear', random_state=1)\nmodel.fit(X_train, y_train)",
#   "import pandas as pd\nimport numpy as np\n\nimport seaborn as sns\nfrom matplotlib import pyplot as plt\nget_ipython().run_line_magic('matplotlib', 'inline')",
#   "# import pandas as pd\ndf = pd.read_csv('https://raw.githubusercontent.com/trob001/Modd4/refs/heads/main/Leads.csv')\ndf.head()",
#   'df.head',
#   'df.shape',
#   'df.head().T',
#   'df.dtypes',
#   "df['TotalVisits'] = pd.to_numeric(df['TotalVisits'], errors='coerce')\ndf['TotalVisits'] = df['TotalVisits'].fillna(0)",
#   'df.info()',
# ...

# %%
df_train_full.lead_number.value_counts()
# Out:
# lead_number
# 0    7392
# Name: count, dtype: int64

# %%
1521/7392
# Out:
# 0.205762987012987

# %%
global_mean = df_train_full.lead_number.mean()
round(global_mean, 3)
# Out:
# 0.0

# %%
categorical = ['Lead_Origin', 'Last_Act', 'Lead_Source' ]
numerical = ['Prospect_ID', 'Lead_Number' , 'Convert' , 'Total_Visits' ]

# %%
categorical = ['lead_origin', 'last_activity', 'lead_source']
numerical = ['prospect_id', 'lead_number', 'converted', 'totalvisits']

# %%
df_train_full[categorical].nunique()
# Out:
# lead_origin       5
# last_activity    16
# lead_source      19
# dtype: int64

# %%
df_train_full[numerical].describe()
# Out:
#        lead_number    converted  totalvisits
# count       7392.0  7392.000000  7392.000000
# mean           0.0     0.383117     3.411661
# std            0.0     0.486179     5.090765
# min            0.0     0.000000     0.000000
# 25%            0.0     0.000000     0.000000
# 50%            0.0     0.000000     3.000000
# 75%            0.0     1.000000     5.000000
# max            0.0     1.000000   251.000000

# %%
from IPython.display import display
global_mean = df_train_full.lead_number.mean()
global_mean
# Out:
# 0.0

# %%
from sklearn.metrics import mutual_info_score
def calculate_mi(series):
    temp_df = pd.DataFrame({'series': series, 'lead_source': df_train_full.lead_source})
    temp_df = temp_df.dropna()
    return mutual_info_score(temp_df['series'], temp_df['lead_source'])

df_mi = df_train_full[categorical].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')

display(df_mi.head())
display(df_mi.tail())
# Out:
#                      MI
# lead_source    1.634838
# lead_origin    0.569111
# last_activity  0.121538
#                      MI
# lead_source    1.634838
# lead_origin    0.569111
# last_activity  0.121538

# %%
# Exclude 'prospect_id' and 'lead_number' from numerical columns
numerical_for_mean = ['converted', 'totalvisits']
df_train_full.groupby(by='lead_source')[numerical_for_mean].mean()
# Out:
#                    converted  totalvisits
# lead_source
# bing                0.166667     2.166667
# blog                0.000000     4.000000
# click2call          0.750000     4.250000
# direct_traffic      0.317624     4.210604
# facebook            0.225000     0.300000
# google              0.400000     4.239651
# live_chat           1.000000     0.000000
# nc_edm              1.000000     7.000000
# olark_chat          0.251768     0.340170
# organic_search      0.374320     5.974973
# pay_per_click_ads   0.000000     3.000000
# press_release       0.000000     9.000000
# reference           0.910588     0.275294
# referral_sites      0.268041     7.412371
# social_media        0.500000     2.500000
# welearn             1.000000     2.000000
# welearnblog_home    0.000000     2.000000
# welingak_website    0.982906     0.128205
# youtubechannel      0.000000     4.000000

# %%
from sklearn.feature_extraction import DictVectorizer

# Remove 'lead_number' from the list of numerical columns
numerical_features = [col for col in numerical if col != 'lead_number']

# Create the dictionary using the modified list of columns
train_dict = df_train[categorical + numerical_features].to_dict(orient='records')

# %%
train_dict[1]
# Out:
# {'lead_origin': 'landing_page_submission',
#  'last_activity': 'sms_sent',
#  'lead_source': 'direct_traffic',
#  'prospect_id': 'e1aac2d6-a6c3-4b67-ae6a-818f7a177b46',
#  'converted': 0,
#  'totalvisits': 2.0}

# %%
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)
# Out:
# DictVectorizer(sparse=False)

# %%
X_train = dv.transform(train_dict)
X_train.shape
# Out:
# (4952, 4994)

# %%
# ipython-input-35-d5e8241e910c
from sklearn.feature_extraction import DictVectorizer
from sklearn.impute import SimpleImputer
import pandas as pd

# Ensure 'lead_number' and other irrelevant columns are excluded
numerical_features = ['totalvisits', 'converted']  # Explicitly define relevant numerical features
categorical = ['lead_origin', 'last_activity', 'lead_source']

# Create the dictionary using the specified columns
train_dict = df_train[categorical + numerical_features].to_dict(orient='records')

# ipython-input-37-d5e8241e910c
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)

# ipython-input-38-d5e8241e910c
X_train = dv.transform(train_dict)
X_train.shape

# Impute missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
X_train = imputer.fit_transform(X_train)

# %%
# ipython-input-53-d5e8241e910c
from sklearn.linear_model import LogisticRegression

# Before fitting the model, ensure X_train and y_train have the same number of samples
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
# Out:
# Shape of X_train: (4952, 42)
# Shape of y_train: (4952,)

# %%
import numpy as np
unique_classes = np.unique(y_train)
print(f"Unique values in y_train: {unique_classes}")
print(f"Class Distribution:\n{pd.Series(y_train).value_counts()}")
# Out:
# Unique values in y_train: [0]
# Class Distribution:
# 0    4952
# Name: count, dtype: int64

# %%
val_dict = df_val[categorical + numerical_features].to_dict(orient='records') # Use numerical_features instead of numerical
X_val = dv.transform(val_dict)

# %%
# ipython-input-65-5f52ba2e518a
from sklearn.feature_extraction import DictVectorizer
from sklearn.impute import SimpleImputer
import pandas as pd

# Ensure 'lead_number' and other irrelevant columns are excluded
numerical_features = ['totalvisits', 'converted']  # Explicitly define relevant numerical features
categorical = ['lead_origin', 'last_activity', 'lead_source']

# Create the dictionary using the specified columns
train_dict = df_train[categorical + numerical_features].to_dict(orient='records')

# Create DictVectorizer and fit
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)

# Transform training data and impute missing values
X_train = dv.transform(train_dict)
imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
X_train = imputer.fit_transform(X_train)


# ----> The changes are in this block <----
# Create the dictionary for validation data
val_dict = df_val[categorical + numerical_features].to_dict(orient='records')

# Transform validation data
X_val = dv.transform(val_dict)

# Impute missing values in validation data using the same imputer fitted on training data
X_val = imputer.transform(X_val) # Apply the transform method to impute missing values

# %%
dv.feature_names_
# Out:
# ['converted',
#  'last_activity',
#  'last_activity=approached_upfront',
#  'last_activity=converted_to_lead',
#  'last_activity=email_bounced',
#  'last_activity=email_link_clicked',
#  'last_activity=email_marked_spam',
#  'last_activity=email_opened',
#  'last_activity=email_received',
#  'last_activity=form_submitted_on_website',
#  'last_activity=had_a_phone_conversation',
#  'last_activity=olark_chat_conversation',
#  'last_activity=page_visited_on_website',
#  'last_activity=resubscribed_to_emails',
#  'last_activity=sms_sent',
#  'last_activity=unreachable',
#  'last_activity=unsubscribed',
#  'last_activity=view_in_browser_link_clicked',
#  'lead_origin=api',
#  'lead_origin=landing_page_submission',
#  'lead_origin=lead_add_form',
#  'lead_origin=lead_import',
#  'lead_origin=quick_add_form',
#  'lead_source',
#  'lead_source=bing',
#  'lead_source=blog',
#  'lead_source=click2call',
#  'lead_source=direct_traffic',
#  'lead_source=facebook',
#  'lead_source=google',
# ...

# %% [markdown]
# Part 2

# %%
# import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/fenago/datasets/refs/heads/main/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
customer = {
    'customerid': '8879-zkjof',
    'gender': 'male',
    'seniorcitizen': 1,
    'partner': 'no',
    'dependents': 'no',
    'tenure': 1,
    'phoneservice': 'yes',
    'multiplelines': 'no',
    'internetservice': 'dsl',
    'onlinesecurity': 'yes',
    'onlinebackup': 'no',
    'deviceprotection': 'yes',
    'techsupport': 'yes',
    'streamingtv': 'yes',
    'streamingmovies': 'yes',
    'contract': 'month-to-month',
    'paperlessbilling': 'yes',
    'paymentmethod': 'bank_transfer_(automatic)',
    'monthlycharges': 379.85,
    'totalcharges': 3320.75,
}

# %%
customer = {
    'gender': 'female',
    'seniorcitizen': 1,
    'partner': 'no',
    'dependents': 'no',
    'phoneservice': 'yes',
    'multiplelines': 'yes',
    'internetservice': 'fiber_optic',
    'onlinesecurity': 'no',
    'onlinebackup': 'no',
    'deviceprotection': 'no',
    'techsupport': 'no',
    'streamingtv': 'yes',
    'streamingmovies': 'no',
    'contract': 'month-to-month',
    'paperlessbilling': 'yes',
    'paymentmethod': 'electronic_check',
    'tenure': 1,
    'monthlycharges': 85.7,
    'totalcharges': 85.7
}

# %% [markdown]
# ---
#
#
# ---
